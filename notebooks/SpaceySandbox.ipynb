# %%
import spacy

# Initial import
from utils import *
# Reload the module to apply changes
import importlib
import utils
importlib.reload(utils)
from utils import *

# %%
# load and prepare text into paragraph chunks using functions found in utils.py
targetText = "little-dorrit"
text = get_text(f"../data/{targetText}.txt")
paragraphs = prepare_text(text)

# %%
nlp = spacy.blank("en")

# %%
print(nlp)

# %%
dir(nlp)

# %%
doc = nlp("Charles Dickens!")
for word in doc:
    print(word.text)

# %%
doc = nlp(paragraphs[456])

# %%
print(doc.text)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(" ".join(paragraphs[0:100]))

# %%
# Iterate over the tokens
for token in doc.ents:
    # Print the text and the predicted part-of-speech tag
    print(token.text, token.label_)

# %%
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

pattern = [{"LEMMA": "stare"}, {"POS": "VERB"}]
matcher.add("RUN_PATTERN", [pattern])

matches = matcher(doc)

# %%
print(matches)

# %%
print("Matches:", [doc[start:end].text for match_id, start, end in matches])

# %%
print(doc)
